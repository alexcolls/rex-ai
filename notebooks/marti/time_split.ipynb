# %%
import pandas as pd
import datetime
import numpy as np
import math

# %% [markdown]
# ## Splitng the date in HOUR - DAY -YEAR

# %%
df = pd.read_csv("../../db/data/merge/volatility/volatility.csv", index_col=0)
# df[["AUD_CAD"]]
# df.index = pd.to_datetime(df.index)
# df['month'] = df.index.month
# df['day_of_year'] = df.index.day_of_year
# df['weekday'] = df.index.weekday
# df['hour'] = df.index.hour
# df["day_of_year"].nunique()
df.iloc[-15:,-20:]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_534/1914855603.py in <module>
# ----> 1 df = pd.read_csv("../../db/data/merge/volatility/volatility.csv", index_col=0)
#       2 # df[["AUD_CAD"]]
#       3 # df.index = pd.to_datetime(df.index)
#       4 # df['month'] = df.index.month
#       5 # df['day_of_year'] = df.index.day_of_year
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     678     kwds.update(kwds_defaults)
#     679
# --> 680     return _read(filepath_or_buffer, kwds)
#     681
#     682
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     932
#     933         self.handles: IOHandles | None = None
# --> 934         self._engine = self._make_engine(f, self.engine)
#     935
#     936     def close(self):
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1216             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1217             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1218             self.handles = get_handle(  # type: ignore[call-overload]
#    1219                 f,
#    1220                 mode,
#
# ~/.pyenv/versions/lewagon/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../db/data/merge/volatility/volatility.csv'

# %%
df = pd.read_csv("../../db/data/merge/volatility/volatility.csv", index_col=0)

# %%
def time_standard(df):
    # Spliting Datetime
    data = pd.DataFrame([])
    df.index = pd.to_datetime(df.index)
    data['month'] = df.index.month
    data['day'] = df.index.day_of_year
    data['weekday'] = df.index.weekday
    data['hour'] = df.index.hour
    
    
    data["month_sin"] = np.sin((np.array(data['month'])*math.pi*2)/12)
    data["month_cos"]=np.cos((np.array(data['month'])*math.pi*2)/12)
    data["day_sin"] = np.sin((np.array(data['day'])*math.pi*2)/360)
    data["day_cos"]=np.cos((np.array(data['day'])*math.pi*2)/360)
    data["weekday_sin"] = np.sin((np.array(data['weekday'])*math.pi*2)/7)
    data["weekday_cos"]=np.cos((np.array(data['weekday'])*math.pi*2)/7)
    data["hour_sin"] = np.sin((np.array(data['hour'])*math.pi*2)/24)
    data["hour_cos"]=np.cos((np.array(data['hour'])*math.pi*2)/24)
    data.drop(columns=['month', 'day','weekday','hour'], inplace=True)
    return data

# %%
df2 = pd.read_csv("../../db/data/merge/secondary/logs_.csv", index_col=0)

# %%
data = time_standard(df2)

# %%
data
# Out:
#            month_sin  month_cos   day_sin   day_cos  weekday_sin  weekday_cos  \
# 0       5.000000e-01   0.866025  0.052336  0.998630     0.000000      1.00000
# 1       5.000000e-01   0.866025  0.052336  0.998630     0.000000      1.00000
# 2       5.000000e-01   0.866025  0.052336  0.998630     0.000000      1.00000
# 3       5.000000e-01   0.866025  0.052336  0.998630     0.000000      1.00000
# 4       5.000000e-01   0.866025  0.052336  0.998630     0.000000      1.00000
# ...              ...        ...       ...       ...          ...          ...
# 111091 -2.449294e-16   1.000000  0.017452  0.999848     0.781831      0.62349
# 111092 -2.449294e-16   1.000000  0.017452  0.999848     0.781831      0.62349
# 111093 -2.449294e-16   1.000000  0.017452  0.999848     0.781831      0.62349
# 111094 -2.449294e-16   1.000000  0.017452  0.999848     0.781831      0.62349
# 111095 -2.449294e-16   1.000000  0.017452  0.999848     0.781831      0.62349
#
#         hour_sin  hour_cos
# 0       0.000000  1.000000
# 1       0.258819  0.965926
# 2       0.500000  0.866025
# 3       0.707107  0.707107
# 4       0.866025  0.500000
# ...          ...       ...
# 111091 -0.965926  0.258819
# 111092 -0.866025  0.500000
# 111093 -0.707107  0.707107
# 111094 -0.500000  0.866025
# 111095 -0.258819  0.965926
#
# [111096 rows x 8 columns]
